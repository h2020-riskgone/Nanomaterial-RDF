# %% [markdown]
# # Extract Molecular Initiating Events from AOP-Wiki for nanomaterials
#
# - Step 1 - Setup
# - Step 2 - Extracting all Molecular Initiating Events
# - Step 3 - Searching the data for Molecular Initiating Events based on literature search outcome
# - Step 4 - Combine, clean and export output

# %% [markdown]
# ## Step 1 - Setup
# ### Imports

# %%
import sys

# !{sys.executable} -m pip install --upgrade pip 
# !{sys.executable} -m pip install watermark

try:
    import pandas as pd
except ImportError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd

try:
    from SPARQLWrapper import SPARQLWrapper, JSON
except ImportError:
    # !{sys.executable} -m pip install sparqlwrapper
    from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ### Functions

# %%
def search(df,term):
    x = set()
    titl = []
    des = []
    for index,row in df.iterrows():
        if term.lower() in row['Title'].lower():
            titl.append(row['ID'])
            x.add(row['ID'])
        if term.lower() in row['Description'].lower():
            des.append(row['ID'])
            x.add(row['ID'])
    if x == set():
        print(term + " not found")
    if titl != []:
        print(term + " found in Title of " + str(','.join(titl)))
    if des != []:
        print(term + " found in Description of " + str(','.join(des)))
    return x

# %% [markdown]
# ## Step 2 - Extracting all Molecular Initiating Events

# %%
sparqlendpoint = SPARQLWrapper("https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/")

# %%
sparqlquery = '''
    SELECT DISTINCT (fn:substring(?MIE_ID,4) as ?ID) (str(?MIE_Title) as ?Title) (str(?MIE_Description) as ?Description) ?MIE
    WHERE {
    # ?AOP a aopo:AdverseOutcomePathway; aopo:has_molecular_initiating_event ?MIE.
    # ?MIE rdfs:label ?MIE_ID; dc:description ?MIE_Description; dc:title ?MIE_Title
    }
    '''

sparqlendpoint.setQuery(sparqlquery)
sparqlendpoint.setReturnFormat(JSON)  
results = sparqlendpoint.query().convert()

df = pd.DataFrame(columns=["ID","Title","Description","URL"])
for result in results["results"]["bindings"]:
    df.loc[len(df.index)] = [result["ID"]["value"],result["Title"]["value"],result["Description"]["value"],result["MIE"]["value"]]

df = df.sort_values(by=['ID'])

display(df)
# Out:
#       ID                                              Title  \
# 23  1002                           Inhibition, Deiodinase 2
# 24  1009                           Inhibition, Deiodinase 1
# 63   112                      Antagonism, Estrogen receptor
# 59  1194                               Increase, DNA damage
# 25    12             Acetylcholinesterase (AchE) Inhibition
# 17   122                Activation, Glucocorticoid Receptor
# 32  1252  Binding to (interferes with) topoisomerase II ...
# 33  1270                              Inactivation of PPARγ
# 36  1386                         CYP7B activity, inhibition
# 37  1391                               Activation of Cyp2E1
# 44  1446    Decrease, Coupling of oxidative phosphorylation
# 26  1487  Binding, Thiol/seleno-proteins involved in pro...
# 35  1490              Inhibition, Fatty Acid Beta Oxidation
# 27  1495  Interaction with the lung resident cell membra...
# 34  1502                     Histone deacetylase inhibition
# 42  1508                                  CYP2E1 Activation
# 43  1509                           Protein Adduct Formation
# 73  1522             Increase, Chitin synthase 1 inhibition
# 18  1539                       Endocytotic lysosomal uptake
# 47  1542     Increase, Mitochondrial complex III antagonism
# 48  1543                Mitochondrial Complex IV inhibition
# 49  1544                 Mitochondrial Complex V inhibition
# 53  1574                            Inhibition, IKK complex
# 54  1580  Binding of microtubule stabilizing agents (MSA...
# 55  1584  Interaction of α-diketones with arginine residues
# 56  1592       ROS generation from photoactivated chemicals
# 57  1604               Inhibition of N-linked glycosylation
# 58  1609  Inhibition, Cytochrome P450 enzyme (CYP17A1) a...
# 60  1632  Increase in reactive oxygen and nitrogen speci...
# 61  1634                  Increase, Oxidative damage to DNA
# ..   ...                                                ...
# 74   396                          Covalent Binding, Protein
# 81   408  reduction in ovarian granulosa cells, Aromatas...
# 45    41         Inhibition, Bile Salt Export Pump (ABCB11)
# 13   424                 Inhibition, Na+/I- symporter (NIS)
# 80   486  systemic inflammation leading to hepatic steat...
# 41    51                            Inhibition, Ca++ ATPase
# 28   559       Activation, Nicotinic acetylcholine receptor
# 31   584                         Inhibition, sodium channel
# 82   593  Inhibition, Ether-a-go-go (ERG) voltage-gated ...
# 83   598                         modulation, sodium channel
# 30   619  Inhibition, 5-hydroxytryptamine transporter (5...
# 0    667  Binding at picrotoxin site, iGABAR chloride ch...
# 3    715       Activation, Constitutive androstane receptor
# 2    718                                   Binding, Tubulin
# 5    766  Inhibition, 4-hydroxyphenyl-pyruvate dioxygena...
# 4    770                Increase, Cytotoxicity (club cells)
# 6    780          Increase, Cytotoxicity (epithelial cells)
# 7    783  Increase, Cytotoxicity (tubular epithelial cells)
# 8    786               Increase, Cytotoxicity (hepatocytes)
# 1     79                Inhibition, Cyclooxygenase activity
# 14   867                         Decrease, Intracellular pH
# 78   875  Binding of agonist, Ionotropic glutamate recep...
# 15   877     Inhibition, organic anion transporter 1 (OAT1)
# 50   887  Inhibition, NADH-ubiquinone oxidoreductase  (c...
# 51   888  Binding of inhibitor, NADH-ubiquinone oxidored...
# 19   941                                   Activation, EGFR
# 21   957                    Binding, Transthyretin in serum
# 16    97                                    Alkylation, DNA
# 22   980                   Inhibition, Calcineurin Activity
# 79   998                  Binding of antagonist, PPAR alpha
#
#                                           Description  \
# 23  Taxonomic: Deiodination by DIO enzymes is know...
# 24  Taxonomic: Deiodination by DIO enzymes is know...
# 63  Taxonomic applicability: Steroid receptors, in...
# 59  DNA nucleotide damage, single, and double stra...
# 25  AChE is present in all life stages of both ver...
# 17  Glucocorticoid receptor is fairly conserved ac...
# 32  DNA topoisomerases are ubiquitous enzymes, whi...
# 33  Following pulmonary exposure, the stressor int...
# 36  CYP7B&nbsp;is known to be conserved in chimpan...
# 37  Taxonomic applicability:&nbsp;The Cyp2E1 gene ...
# 44  Taxonomic applicability domain\n\nThis key eve...
# 26  Due to the ubiquitous distribution of the SH-/...
# 35          This is a well-known metabolic pathway.\n
# 27  Although the expression of DAMPs following exp...
# 34  The inhibition of HDAC by HDIs is well conserv...
# 42  CYP2E1 is an enzyme which is part of the cytoc...
# 43  Reactive chemicals or metabolites can interact...
# 73  Taxonomic: Effect data for the occurrence of C...
# 18  Endocytosis is an universal internalization ro...
# 47  The mitochondrial complex III (mitochondrial c...
# 48  The mitochondrial complex IV (Cytochrome c oxi...
# 49  The mitochondrial complex V (ATPase) is an enz...
# 53  The IKK complex consists of 3 subunits: IKKa, ...
# 54  MSAs bind to polymerized tubulin. [1, 2] In se...
# 55  The electrophilic &alpha;-diketones interact w...
# 56  Chemicals: This MIE applies to a wide range of...
# 57  The ER, glycosylation is performed to newly sy...
# 58  Cyp17a1 inhibitors bind in the active site of ...
# 60    This KE is broadly applicable across species.\n
# 61  Theoretically, DNA oxidation can occur in any ...
# ..                                                ...
# 74  The OECD 2012 document does not indicate in vi...
# 81  Aromatase (CYP19) orthologs are known to be pr...
# 45  The BSEP transporter protein is a prominent ad...
# 13  Apart from the human, functional NIS protein h...
# 80  Systemic inflammation causes release of inflam...
# 41  Pb(II) has been shown to decrease Ca++ ATPase ...
# 28  Text from LaLone et al. (2017) Weight of evide...
# 31  Voltage-gated sodium channels consist of an al...
# 82  ERG mRNA has been identified in the hearts of ...
# 83  Voltage-gated sodium channels present on neuro...
# 30  Inhibitors of the serotonin reuptake transport...
# 0   Theoretically, this MIE is applicable to any o...
# 3   CAR (NR1I3) is evolutionarily conserved across...
# 2   Chemical binding to tubulin has been measured ...
# 5   This key event commonly operates through HPPD ...
# 4   This key event can be associated with Cyp2f2 b...
# 6   This key event is often associated with gavage...
# 7   This key event can be associated with Cyp2e1-m...
# 8   This key event is mediated by Nrf2-related gen...
# 1   There is a high level of conservation of this ...
# 14  All cells regulate intracellular pH and produc...
# 78   The major determinants for ligand e.g. for bo...
# 15  Inhibition of the organic anion transporters (...
# 50  The CI is well-conserved across species from l...
# 51  CI has a highly conserved subunit composition ...
# 19  EGFR activation in human, mouse and rat is wel...
# 21  The transthyretin protein has been found to be...
# 16  Alkylated DNA has been measured in somatic cel...
# 22  CN is broadly distributed in T-cells, B‑cells,...
# 79  The fundamental mechanics for nuclear receptor...
#
#                                         URL
# 23  https://identifiers.org/aop.events/1002
# 24  https://identifiers.org/aop.events/1009
# 63   https://identifiers.org/aop.events/112
# 59  https://identifiers.org/aop.events/1194
# 25    https://identifiers.org/aop.events/12
# 17   https://identifiers.org/aop.events/122
# 32  https://identifiers.org/aop.events/1252
# 33  https://identifiers.org/aop.events/1270
# 36  https://identifiers.org/aop.events/1386
# 37  https://identifiers.org/aop.events/1391
# 44  https://identifiers.org/aop.events/1446
# 26  https://identifiers.org/aop.events/1487
# 35  https://identifiers.org/aop.events/1490
# 27  https://identifiers.org/aop.events/1495
# 34  https://identifiers.org/aop.events/1502
# 42  https://identifiers.org/aop.events/1508
# 43  https://identifiers.org/aop.events/1509
# 73  https://identifiers.org/aop.events/1522
# 18  https://identifiers.org/aop.events/1539
# 47  https://identifiers.org/aop.events/1542
# 48  https://identifiers.org/aop.events/1543
# 49  https://identifiers.org/aop.events/1544
# 53  https://identifiers.org/aop.events/1574
# 54  https://identifiers.org/aop.events/1580
# 55  https://identifiers.org/aop.events/1584
# 56  https://identifiers.org/aop.events/1592
# 57  https://identifiers.org/aop.events/1604
# 58  https://identifiers.org/aop.events/1609
# 60  https://identifiers.org/aop.events/1632
# 61  https://identifiers.org/aop.events/1634
# ..                                      ...
# 74   https://identifiers.org/aop.events/396
# 81   https://identifiers.org/aop.events/408
# 45    https://identifiers.org/aop.events/41
# 13   https://identifiers.org/aop.events/424
# 80   https://identifiers.org/aop.events/486
# 41    https://identifiers.org/aop.events/51
# 28   https://identifiers.org/aop.events/559
# 31   https://identifiers.org/aop.events/584
# 82   https://identifiers.org/aop.events/593
# 83   https://identifiers.org/aop.events/598
# 30   https://identifiers.org/aop.events/619
# 0    https://identifiers.org/aop.events/667
# 3    https://identifiers.org/aop.events/715
# 2    https://identifiers.org/aop.events/718
# 5    https://identifiers.org/aop.events/766
# 4    https://identifiers.org/aop.events/770
# 6    https://identifiers.org/aop.events/780
# 7    https://identifiers.org/aop.events/783
# 8    https://identifiers.org/aop.events/786
# 1     https://identifiers.org/aop.events/79
# 14   https://identifiers.org/aop.events/867
# 78   https://identifiers.org/aop.events/875
# 15   https://identifiers.org/aop.events/877
# 50   https://identifiers.org/aop.events/887
# 51   https://identifiers.org/aop.events/888
# 19   https://identifiers.org/aop.events/941
# 21   https://identifiers.org/aop.events/957
# 16    https://identifiers.org/aop.events/97
# 22   https://identifiers.org/aop.events/980
# 79   https://identifiers.org/aop.events/998
#
# [84 rows x 4 columns]

# %% [markdown]
# ## Step 3 - Searching the data for Molecular Initiating Events based on literature search outcome

# %%
searchterms = ['reactive oxygen species','ROS formation','ROS generation']

# %%
for item in searchterms:
    output = search(df,item)
    if not output == set():
        print(str(item) + ' gives ' + str(output))
# Out:
# reactive oxygen species found in Title of 1753
# reactive oxygen species found in Description of 1194
# reactive oxygen species gives {'1194', '1753'}
# ROS formation not found
# ROS generation found in Title of 1592
# ROS generation gives {'1592'}

# %%
## some are missing, because our SPARQL query filters the one that are indicated as MIE for AOPs. We could filter to be "molecular" instead for more results
