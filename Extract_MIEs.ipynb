# %% [markdown]
# # Extract Molecular Initiating Events from AOP-Wiki for nanomaterials
#
# - Step 1 - Setup
# - Step 2 - Extracting all Molecular Initiating Events
# - Step 3 - Searching the data for Molecular Initiating Events based on literature search outcome
# - Step 4 - Combine, clean and export output

# %% [markdown]
# ## Step 1 - Setup
# ### Imports

# %%
import sys

# !{sys.executable} -m pip install --upgrade pip 
# !{sys.executable} -m pip install watermark

try:
    import pandas as pd
except ImportError:
    # !{sys.executable} -m pip install pandas
    import pandas as pd

try:
    from SPARQLWrapper import SPARQLWrapper, JSON
except ImportError:
    # !{sys.executable} -m pip install sparqlwrapper
    from SPARQLWrapper import SPARQLWrapper, JSON
#pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 99999)
pd.set_option('display.max_columns', 99999)
# Out:
# Requirement already satisfied: pip in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (21.1.2)
# Requirement already satisfied: watermark in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (1.8.1)
# Requirement already satisfied: ipython in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from watermark) (7.6.1)
# Requirement already satisfied: decorator in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (4.4.0)
# Requirement already satisfied: traitlets>=4.2 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (4.3.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (2.0.9)
# Requirement already satisfied: pygments in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (2.4.2)
# Requirement already satisfied: setuptools>=18.5 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (41.0.1)
# Requirement already satisfied: pexpect in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (4.7.0)
# Requirement already satisfied: jedi>=0.10 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (0.13.3)
# Requirement already satisfied: pickleshare in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: backcall in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from ipython->watermark) (0.1.0)
# Requirement already satisfied: parso>=0.3.0 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython->watermark) (0.5.0)
# Requirement already satisfied: wcwidth in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->watermark) (0.1.7)
# Requirement already satisfied: six>=1.9.0 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->watermark) (1.12.0)
# Requirement already satisfied: ipython-genutils in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->ipython->watermark) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/marvin.martens/anaconda3/lib/python3.7/site-packages (from pexpect->ipython->watermark) (0.6.0)

# %% [markdown]
# ### Functions

# %%
def search(df,term):
    x = set()
    titl = []
    des = []
    for index,row in df.iterrows():
        if term.lower() in row['Title'].lower():
            titl.append(row['ID'])
            x.add(row['ID'])
        if term.lower() in row['Description'].lower():
            des.append(row['ID'])
            x.add(row['ID'])
    if x == set():
        print(term + " not found")
    if titl != []:
        print(term + " found in Title of " + str(','.join(titl)))
    if des != []:
        print(term + " found in Description of " + str(','.join(des)))
    return x

# %% [markdown]
# ## Step 2 - Extracting all Molecular Initiating Events

# %%
sparqlendpoint = SPARQLWrapper("http://localhost:8890/sparql/")

# %%
sparqlquery = '''
    SELECT DISTINCT (fn:substring(?MIE_ID,4) as ?ID) (str(?MIE_Title) as ?Title) ?MIE
    WHERE {
    # ?AOP a aopo:AdverseOutcomePathway; aopo:has_molecular_initiating_event ?MIE.
    # ?MIE rdfs:label ?MIE_ID; dc:title ?MIE_Title
    }
    '''

sparqlendpoint.setQuery(sparqlquery)
sparqlendpoint.setReturnFormat(JSON)  
results = sparqlendpoint.query().convert()

df = pd.DataFrame(columns=["ID","Title","URL"])
for result in results["results"]["bindings"]:
    df.loc[len(df.index)] = [result["ID"]["value"],result["Title"]["value"],result["MIE"]["value"]]

df = df.sort_values(by=['ID'])

display(df)
# Out:
#        ID                                              Title  \
# 0    1002                           Inhibition, Deiodinase 2
# 1    1009                           Inhibition, Deiodinase 1
# 44   1018      Activation, Glutamate-gated chloride channels
# 45   1028  Activation of specific nuclear receptors, PPAR...
# 46    103                Increase, Ecdysone receptor agonism
# 47   1038             Activation, beta-2 adrenergic receptor
# 48   1064  prepubertal increase, Estrogen receptor (ER) a...
# 49   1103              Inhibition, Cyclooxygenase 1 activity
# 50    111                         Agonism, Estrogen receptor
# 51   1114                                       Unknown, MIE
# 2     112                      Antagonism, Estrogen receptor
# 52   1134  Irreversible inhibition of hepatic VKOR by bin...
# 53   1138  Uncoupling of oxidative phosphorylation, Reduc...
# 54   1152          Inhibition, Iodotyrosine deiodinase (IYD)
# 55   1153                           Inhibition, Deiodinase 3
# 56   1155                                Inhibition, Pendrin
# 57   1156                           Inhibition, Dual oxidase
# 58   1157            Activation, Hepatic nuclear receptor(s)
# 59   1169  Anticoagulant rodenticide interferes with carb...
# 60   1174                          Activation, NADPH Oxidase
# 61   1181                      Activation, Estrogen receptor
# 62   1194                               Increase, DNA damage
# 3      12             Acetylcholinesterase (AchE) Inhibition
# 63   1205              Activation, Juvenile hormone receptor
# 64   1215                   TRPA1 activation, TRPA1 Receptor
# 65    122                Activation, Glucocorticoid Receptor
# 66   1252  Binding to (interferes with) topoisomerase II ...
# 67   1258                             Decompartmentalization
# 68   1259                                           narcosis
# 69   1260                    Direct mitochondrial inhibition
# 70   1261                           Mitochondrial impairment
# 71   1270                              Inactivation of PPARγ
# 72   1317          Decreased, serotonin transporter activity
# 73   1349                    Activated, presynaptic neuron 1
# 74   1386                         CYP7B activity, inhibition
# 4    1391                               Activation of Cyp2E1
# 75   1396        Increased, glucocorticoid receptor activity
# 76   1397          Increased, serotonin transporter activity
# 77   1402                            Reduced, PTGS1 function
# 78   1408                            Reduced, PTGS2 function
# 79   1412                      Helicobacter pylori infection
# 80   1413             Reduced, presynaptic neuron 2 activity
# 81   1417                               NFE2/Nrf2 repression
# 82   1425                         Mu Opioid Receptor Agonism
# 83   1431                      Serotonin 1A Receptor Agonism
# 84   1437         Sensing of the stressor by pulmonary cells
# 85   1446    Decrease, Coupling of oxidative phosphorylation
# 86   1454                              chronic high fat diet
# 87   1462  Thiol group of chemicals interact with sulfuhy...
# 88   1468  Activation, Latent Transforming Growth Factor ...
# 89   1471       Increase, Uncoupling of photophosphorylation
# 90   1481  Inhibition of mitochondrial DNA polymerase gam...
# 91   1486           Binding of substrate, endocytic receptor
# 92   1487  Binding, Thiol/seleno-proteins involved in pro...
# 93   1490              Inhibition, Fatty Acid Beta Oxidation
# 94   1495  Interaction with the lung resident cell membra...
# 5    1502                     Histone deacetylase inhibition
# 6    1508                                  CYP2E1 Activation
# 95   1509                           Protein Adduct Formation
# 7    1522                      Inhibition, Chitin synthase 1
# 96   1525            Increase, Sulfonylurea receptor binding
# 97   1529                 Blockade, L-Type Calcium Channels
# 98   1539                       Endocytotic lysosomal uptake
# 8    1542     Increase, Mitochondrial complex III antagonism
# 9    1543                Mitochondrial Complex IV inhibition
# 10   1544                 Mitochondrial Complex V inhibition
# 11   1574                            Inhibition, IKK complex
# 99   1580  Binding of microtubule stabilizing agents (MSA...
# 100  1584  Interaction of α-diketones with arginine residues
# 101  1592       ROS generation from photoactivated chemicals
# 12   1604               Inhibition of N-linked glycosylation
# 102  1609  Inhibition, Cytochrome P450 enzyme (CYP17A1) a...
# 103  1617                           5α-reductase, inhibition
# 104  1619         Increase, DNA methyltransferase inhibition
# 105  1627                          Inhibition of tyrosinase
# 106  1632  Increase in reactive oxygen and nitrogen speci...
# 107  1634                  Increase, Oxidative damage to DNA
# 108  1637             Retinaldehyde dehydrogenase inhibition
# 13    165  Activation, Long term AHR receptor driven dire...
# 109  1653  Binding of inhibitor to mitochondrial complex III
# 110  1654   Binding of inhibitor to mitochondrial complex IV
# 111  1655    Binding of inhibitor to mitochondrial complex V
# 14   1656                      Antagonism, Thyroid Receptor
# 112  1657          Inhibition of cystathionine beta-synthase
# 113  1668                             Frustrated phagoytosis
# 15    167                                    Activation, LXR
# 114  1672             Inhibition of lung surfactant function
# 115  1680                                   Inhibition, TBX1
# 116  1686                        Direct Deposition of Energy
# 117  1691                             Antagonism,LH receptor
# 16   1700                          Impaired IL-1R1 signaling
# 17   1706                                Stimulation, TLR7/8
# 18   1710  Binding to estrogen receptor (ER)-α in immune ...
# 19   1715                                 Inhibition of JAK3
# 20   1720                                 Trypsin inhibition
# 118  1738          Increased viral entry and gene expression
# 21   1739                   ACE2 binding to viral S-protein
# 119  1740                                    ACE2 inhibition
# 120  1753                    Chronic reactive oxygen species
# 121  1765           Increase, Formation of DNA photoproducts
# 122   177                   N/A, Mitochondrial dysfunction 1
# 123  1785    Increase, Mitochondrial ATP synthase antagonism
# 124  1792                    Toll-like receptor 4 activation
# 125  1796                         11β-hydroxylase inhibition
# 126  1799                             Inhibition of 11β-HSD
# 22     18                                    Activation, AhR
# 127  1806                     Increase, Chitinase inhibition
# 128  1807                    Increase, Chitobiase inhibition
# 129  1814  benzoquinone imine and acylglucuronide metabol...
# 130  1831         Binding, Thyroid binding globulin in serum
# 131  1840                     Inhibition, cytochrome oxidase
# 132  1842                          Prolonged TLR9 activation
# 133  1847  Coronaviral replication / RNA genome transcrip...
# 23   1848     Induced Toll Like Receptor (TLR) Dysregulation
# 134  1851  Binding of agonist, Angiotensin II receptor ty...
# 135  1853            Hyperactivation of ACE/Ang-II/AT1R axis
# 24    201              Binding of antagonist, NMDA receptors
# 136   209                                  Peptide Oxidation
# 137   213  N/A, Parent compound is converted to the react...
# 138   227                                  Activation, PPARα
# 139   228  peroxisome proliferator activated receptor pro...
# 140   231                   Decreased, PPAR-alpha activation
# 141   232                    Decreased, PPAR-beta activation
# 142   233                   Decreased, PPAR-gamma activation
# 143   239             Activation, Pregnane-X receptor, NR1l2
# 144   244                                Alkylation, Protein
# 145   245                                Activation, PXR/SXR
# 146    25                         Agonism, Androgen receptor
# 147   257       Increase, Reactive oxygen species production
# 25     26                      Antagonism, Androgen receptor
# 148    27                 N/A, Androgen receptor, Antagonism
# 26    277               Thyroid hormone synthesis, Decreased
# 27    279                        Thyroperoxidase, Inhibition
# 149   294                                       N/A, Unknown
# 28    305                                 Inhibition, VegfR2
# 29     36                              Inhibition, Aromatase
# 150   373               Formation, Pro-mutagenic DNA Adducts
# 151   396                          Covalent Binding, Protein
# 30    408  reduction in ovarian granulosa cells, Aromatas...
# 31     41         Inhibition, Bile Salt Export Pump (ABCB11)
# 32    424                 Inhibition, Na+/I- symporter (NIS)
# 152   456  Suppression, Constitutive androstane receptor,...
# 153    46                 Accumulation, Biological membranes
# 154   461                             Suppression, HNF4alpha
# 155   468                             Inhibition, PPAR alpha
# 156   478                                   Activation, NRF2
# 157   479                                  Activation, NR1H4
# 158   486  systemic inflammation leading to hepatic steat...
# 159   494        Glucocorticoid Receptor Agonist, Activation
# 33     51                            Inhibition, Ca++ ATPase
# 160   526  Inhibition, Inhibition of Dopamine-beta-hydrox...
# 161   559       Activation, Nicotinic acetylcholine receptor
# 34    584                         Inhibition, sodium channel
# 162   593  Inhibition, Ether-a-go-go (ERG) voltage-gated ...
# 163   598                         modulation, sodium channel
# 35    619  Inhibition, 5-hydroxytryptamine transporter (5...
# 164   638                Antagonism, Histamine Receptor (H2)
# 165   640  Decreased steroidogenesis, Proteomic alteratio...
# 166   642  Decreased Cholesterol, Decreased De Novo Biosy...
# 167   643  Decreased Cholesterol, Decreased Uptake of Lip...
# 168   644  Decreased Cholesterol, Decreased Transport of ...
# 169   650  Stimulation of adult Leydig cells via the Adre...
# 170   653  Decreased testosterone by the fetal Leydig cel...
# 171   654  Decreased testosterone by the fetal Leydig cel...
# 172   658  Decreased testosterone by the fetal Leydig cel...
# 173   659  Decreased testosterone by the fetal Leydig cel...
# 174   661  Decreased testosterone by the fetal Leydig cel...
# 175   662  Decreased testosterone by the fetal Leydig cel...
# 176   667  Binding at picrotoxin site, iGABAR chloride ch...
# 177   697                             impaired, ion channels
# 178   714      Increased, Binding of chemicals to 2u (serum)
# 36    715       Activation, Constitutive androstane receptor
# 179   718                                   Binding, Tubulin
# 180   724  Inhibition, Pyruvate dehydrogenase kinase (PDK...
# 181   737              Decreased, Uptake of inorganic iodide
# 182   742              Decreased, Androgen receptor activity
# 183   746                    Increase, Dopaminergic activity
# 184   760       Activation, Glutamate-gated chloride channel
# 185   762  Activation, ionotropic GABA Receptor chloride ...
# 186   766  Inhibition, 4-hydroxyphenyl-pyruvate dioxygena...
# 187   770                Increase, Cytotoxicity (club cells)
# 188   780          Increase, Cytotoxicity (epithelial cells)
# 189   783  Increase, Cytotoxicity (tubular epithelial cells)
# 190   785                      Activation, Androgen receptor
# 191   786               Increase, Cytotoxicity (hepatocytes)
# 37     79                Inhibition, Cyclooxygenase activity
# 192   790                  Inhibition, 5α-reductase activity
# 193   793                  Increase, Urinary bladder calculi
# 194   798                    Inhibition, Prolyl hydroxylases
# 195   801                                modulation, Unknown
# 196   804                      Inhibition, HMG-CoA reductase
# 197   828                        Inhibition, Phospholipase A
# 198   849               Inhibition, Antgonism of NE receptor
# 199   867                         Decrease, Intracellular pH
# 200   875  Binding of agonist, Ionotropic glutamate recep...
# 38    877     Inhibition, organic anion transporter 1 (OAT1)
# 39    887  Inhibition, NADH-ubiquinone oxidoreductase  (c...
# 40    888  Binding of inhibitor, NADH-ubiquinone oxidored...
# 201     9                                  Activation, 5HT2c
# 41    941                                   Activation, EGFR
# 42    957                    Binding, Transthyretin in serum
# 202   964  Inhibition of Aromatase Enzyme, Chemical expos...
# 203    97                                    Alkylation, DNA
# 43    980                   Inhibition, Calcineurin Activity
# 204   998                  Binding of antagonist, PPAR alpha
#
#                                          URL
# 0    https://identifiers.org/aop.events/1002
# 1    https://identifiers.org/aop.events/1009
# 44   https://identifiers.org/aop.events/1018
# 45   https://identifiers.org/aop.events/1028
# 46    https://identifiers.org/aop.events/103
# 47   https://identifiers.org/aop.events/1038
# 48   https://identifiers.org/aop.events/1064
# 49   https://identifiers.org/aop.events/1103
# 50    https://identifiers.org/aop.events/111
# 51   https://identifiers.org/aop.events/1114
# 2     https://identifiers.org/aop.events/112
# 52   https://identifiers.org/aop.events/1134
# 53   https://identifiers.org/aop.events/1138
# 54   https://identifiers.org/aop.events/1152
# 55   https://identifiers.org/aop.events/1153
# 56   https://identifiers.org/aop.events/1155
# 57   https://identifiers.org/aop.events/1156
# 58   https://identifiers.org/aop.events/1157
# 59   https://identifiers.org/aop.events/1169
# 60   https://identifiers.org/aop.events/1174
# 61   https://identifiers.org/aop.events/1181
# 62   https://identifiers.org/aop.events/1194
# 3      https://identifiers.org/aop.events/12
# 63   https://identifiers.org/aop.events/1205
# 64   https://identifiers.org/aop.events/1215
# 65    https://identifiers.org/aop.events/122
# 66   https://identifiers.org/aop.events/1252
# 67   https://identifiers.org/aop.events/1258
# 68   https://identifiers.org/aop.events/1259
# 69   https://identifiers.org/aop.events/1260
# 70   https://identifiers.org/aop.events/1261
# 71   https://identifiers.org/aop.events/1270
# 72   https://identifiers.org/aop.events/1317
# 73   https://identifiers.org/aop.events/1349
# 74   https://identifiers.org/aop.events/1386
# 4    https://identifiers.org/aop.events/1391
# 75   https://identifiers.org/aop.events/1396
# 76   https://identifiers.org/aop.events/1397
# 77   https://identifiers.org/aop.events/1402
# 78   https://identifiers.org/aop.events/1408
# 79   https://identifiers.org/aop.events/1412
# 80   https://identifiers.org/aop.events/1413
# 81   https://identifiers.org/aop.events/1417
# 82   https://identifiers.org/aop.events/1425
# 83   https://identifiers.org/aop.events/1431
# 84   https://identifiers.org/aop.events/1437
# 85   https://identifiers.org/aop.events/1446
# 86   https://identifiers.org/aop.events/1454
# 87   https://identifiers.org/aop.events/1462
# 88   https://identifiers.org/aop.events/1468
# 89   https://identifiers.org/aop.events/1471
# 90   https://identifiers.org/aop.events/1481
# 91   https://identifiers.org/aop.events/1486
# 92   https://identifiers.org/aop.events/1487
# 93   https://identifiers.org/aop.events/1490
# 94   https://identifiers.org/aop.events/1495
# 5    https://identifiers.org/aop.events/1502
# 6    https://identifiers.org/aop.events/1508
# 95   https://identifiers.org/aop.events/1509
# 7    https://identifiers.org/aop.events/1522
# 96   https://identifiers.org/aop.events/1525
# 97   https://identifiers.org/aop.events/1529
# 98   https://identifiers.org/aop.events/1539
# 8    https://identifiers.org/aop.events/1542
# 9    https://identifiers.org/aop.events/1543
# 10   https://identifiers.org/aop.events/1544
# 11   https://identifiers.org/aop.events/1574
# 99   https://identifiers.org/aop.events/1580
# 100  https://identifiers.org/aop.events/1584
# 101  https://identifiers.org/aop.events/1592
# 12   https://identifiers.org/aop.events/1604
# 102  https://identifiers.org/aop.events/1609
# 103  https://identifiers.org/aop.events/1617
# 104  https://identifiers.org/aop.events/1619
# 105  https://identifiers.org/aop.events/1627
# 106  https://identifiers.org/aop.events/1632
# 107  https://identifiers.org/aop.events/1634
# 108  https://identifiers.org/aop.events/1637
# 13    https://identifiers.org/aop.events/165
# 109  https://identifiers.org/aop.events/1653
# 110  https://identifiers.org/aop.events/1654
# 111  https://identifiers.org/aop.events/1655
# 14   https://identifiers.org/aop.events/1656
# 112  https://identifiers.org/aop.events/1657
# 113  https://identifiers.org/aop.events/1668
# 15    https://identifiers.org/aop.events/167
# 114  https://identifiers.org/aop.events/1672
# 115  https://identifiers.org/aop.events/1680
# 116  https://identifiers.org/aop.events/1686
# 117  https://identifiers.org/aop.events/1691
# 16   https://identifiers.org/aop.events/1700
# 17   https://identifiers.org/aop.events/1706
# 18   https://identifiers.org/aop.events/1710
# 19   https://identifiers.org/aop.events/1715
# 20   https://identifiers.org/aop.events/1720
# 118  https://identifiers.org/aop.events/1738
# 21   https://identifiers.org/aop.events/1739
# 119  https://identifiers.org/aop.events/1740
# 120  https://identifiers.org/aop.events/1753
# 121  https://identifiers.org/aop.events/1765
# 122   https://identifiers.org/aop.events/177
# 123  https://identifiers.org/aop.events/1785
# 124  https://identifiers.org/aop.events/1792
# 125  https://identifiers.org/aop.events/1796
# 126  https://identifiers.org/aop.events/1799
# 22     https://identifiers.org/aop.events/18
# 127  https://identifiers.org/aop.events/1806
# 128  https://identifiers.org/aop.events/1807
# 129  https://identifiers.org/aop.events/1814
# 130  https://identifiers.org/aop.events/1831
# 131  https://identifiers.org/aop.events/1840
# 132  https://identifiers.org/aop.events/1842
# 133  https://identifiers.org/aop.events/1847
# 23   https://identifiers.org/aop.events/1848
# 134  https://identifiers.org/aop.events/1851
# 135  https://identifiers.org/aop.events/1853
# 24    https://identifiers.org/aop.events/201
# 136   https://identifiers.org/aop.events/209
# 137   https://identifiers.org/aop.events/213
# 138   https://identifiers.org/aop.events/227
# 139   https://identifiers.org/aop.events/228
# 140   https://identifiers.org/aop.events/231
# 141   https://identifiers.org/aop.events/232
# 142   https://identifiers.org/aop.events/233
# 143   https://identifiers.org/aop.events/239
# 144   https://identifiers.org/aop.events/244
# 145   https://identifiers.org/aop.events/245
# 146    https://identifiers.org/aop.events/25
# 147   https://identifiers.org/aop.events/257
# 25     https://identifiers.org/aop.events/26
# 148    https://identifiers.org/aop.events/27
# 26    https://identifiers.org/aop.events/277
# 27    https://identifiers.org/aop.events/279
# 149   https://identifiers.org/aop.events/294
# 28    https://identifiers.org/aop.events/305
# 29     https://identifiers.org/aop.events/36
# 150   https://identifiers.org/aop.events/373
# 151   https://identifiers.org/aop.events/396
# 30    https://identifiers.org/aop.events/408
# 31     https://identifiers.org/aop.events/41
# 32    https://identifiers.org/aop.events/424
# 152   https://identifiers.org/aop.events/456
# 153    https://identifiers.org/aop.events/46
# 154   https://identifiers.org/aop.events/461
# 155   https://identifiers.org/aop.events/468
# 156   https://identifiers.org/aop.events/478
# 157   https://identifiers.org/aop.events/479
# 158   https://identifiers.org/aop.events/486
# 159   https://identifiers.org/aop.events/494
# 33     https://identifiers.org/aop.events/51
# 160   https://identifiers.org/aop.events/526
# 161   https://identifiers.org/aop.events/559
# 34    https://identifiers.org/aop.events/584
# 162   https://identifiers.org/aop.events/593
# 163   https://identifiers.org/aop.events/598
# 35    https://identifiers.org/aop.events/619
# 164   https://identifiers.org/aop.events/638
# 165   https://identifiers.org/aop.events/640
# 166   https://identifiers.org/aop.events/642
# 167   https://identifiers.org/aop.events/643
# 168   https://identifiers.org/aop.events/644
# 169   https://identifiers.org/aop.events/650
# 170   https://identifiers.org/aop.events/653
# 171   https://identifiers.org/aop.events/654
# 172   https://identifiers.org/aop.events/658
# 173   https://identifiers.org/aop.events/659
# 174   https://identifiers.org/aop.events/661
# 175   https://identifiers.org/aop.events/662
# 176   https://identifiers.org/aop.events/667
# 177   https://identifiers.org/aop.events/697
# 178   https://identifiers.org/aop.events/714
# 36    https://identifiers.org/aop.events/715
# 179   https://identifiers.org/aop.events/718
# 180   https://identifiers.org/aop.events/724
# 181   https://identifiers.org/aop.events/737
# 182   https://identifiers.org/aop.events/742
# 183   https://identifiers.org/aop.events/746
# 184   https://identifiers.org/aop.events/760
# 185   https://identifiers.org/aop.events/762
# 186   https://identifiers.org/aop.events/766
# 187   https://identifiers.org/aop.events/770
# 188   https://identifiers.org/aop.events/780
# 189   https://identifiers.org/aop.events/783
# 190   https://identifiers.org/aop.events/785
# 191   https://identifiers.org/aop.events/786
# 37     https://identifiers.org/aop.events/79
# 192   https://identifiers.org/aop.events/790
# 193   https://identifiers.org/aop.events/793
# 194   https://identifiers.org/aop.events/798
# 195   https://identifiers.org/aop.events/801
# 196   https://identifiers.org/aop.events/804
# 197   https://identifiers.org/aop.events/828
# 198   https://identifiers.org/aop.events/849
# 199   https://identifiers.org/aop.events/867
# 200   https://identifiers.org/aop.events/875
# 38    https://identifiers.org/aop.events/877
# 39    https://identifiers.org/aop.events/887
# 40    https://identifiers.org/aop.events/888
# 201     https://identifiers.org/aop.events/9
# 41    https://identifiers.org/aop.events/941
# 42    https://identifiers.org/aop.events/957
# 202   https://identifiers.org/aop.events/964
# 203    https://identifiers.org/aop.events/97
# 43    https://identifiers.org/aop.events/980
# 204   https://identifiers.org/aop.events/998

# %%
len(df)
# Out:
# 205

# %% [markdown]
# ## Step 3 - Searching the data for Molecular Initiating Events based on literature search outcome

# %%
searchterms = ['reactive oxygen species','ROS formation','ROS generation','Cellular sensing of substance or substance induced damage','Induction of IL1β and TNFα','Cellular sensing of the substance-induced damage resulting in the release of danger signals','Lysosomal injury','No effect','ROS production','DNA damage','interruption of calcium sensing receptors','production of free radicals','induction of IL6','interference with signalling molecules','activation of signalling molecules','inhibition of cellular receptors (dopaminergic, adrenergic, cannabinoid)','DNA damage','apoptotic stimuli','decreased inflammatory response','histone modifications','Pulmonary inflammation','genotoxicity','cell cycle regulation/progression/control','apoptosis','proliferation','pulmonary and cardiac effects','carcinogenicity','ROS (increases in the levels of malondialdehyde (MDA))','mitochondrial dysfunction','the toxicity in the rats dosed with copper microparticles was negligible','ROS production through endoplasmic reticulum stress','activation of Nrf2 singling pathway and increased catalase activity','promoted activities of SOD and Gpx','activating the NLRP3 inflammasomesactivation of post-transcriptional mechanism','condensed cellular size with reduced numbers of protrusions','increased the number and length of protrusions','induction of oxidative stress','disrupt macrophage function','Direct stress of epithelium','Alveolar Macrophage activation','reactions with endogenous molecules','surface silanol disorganization','inducing membranolysis','Alter genome methylation','Interaction with cell membrane','DNA','cell death','mitochondrial','ROS ']

# %%
#for item in searchterms:
#    output = search(df,item)
#    if not output == set():
#        print(str(item) + ' gives ' + str(output))

# %%
## some are missing, because our SPARQL query filters the one that are indicated as MIE for AOPs. We could filter to be "molecular" instead for more results
